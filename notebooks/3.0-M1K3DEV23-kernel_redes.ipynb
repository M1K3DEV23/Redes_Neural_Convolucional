# %% [markdown]
# # El Kernel en acción
#
# Creemos nuestro ejemplo de kernel horizontal y vertical, utilizando una imagen nuestra como base.

# %%
# %load_ext autoreload
# %autoreload 1

# %%
import os
import sys

sys.path.append(os.path.dirname(os.path.abspath(os.path.abspath(""))))

# %% [markdown]
# ## 1: importando bibliotecas

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.ndimage as nd
from skimage import color, io

# %% [markdown]
# ## 2: Abrimos nuestra imagen y la convertimos a gris

# %%
img = io.imread("../data/yo.png")

# %%
print("Original image shape: ", img.shape)
# Out:
# Original image shape:  (428, 437, 3)

# %%
img_gray = color.rgb2gray(img)
print("Grayscale image shape: ", img_gray.shape)
# Out:
# Grayscale image shape:  (428, 437)

# %% [markdown]
# Vemos como la imagen original tiene 3 canales RGB mientras que la imagen en escala de Grises no tiene una tercera dimensión.

# %% [markdown]
# ## 3: Creamos nuestros kernels vertical y horizontal

# %%
# Kernel para detección de bordes verticales

kernel_v = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])

# Kernel para deteción de bordes horizontales
kernel_h = np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]])

# %% [markdown]
# ## 4: Aplicamos la convolución a la imagen en escala de grises

# %%
img_kernel_v = nd.convolve(img_gray, kernel_v)
img_kernel_h = nd.convolve(img_gray, kernel_h)

# %% [markdown]
# ## 5: Graficamos los resultados

# %%
fig, ax = plt.subplots(2, 2)

ax[0, 0].imshow(img)
ax[0, 0].set_title("Original")
ax[0, 0].axis("off")

#
ax[0, 1].imshow(img_gray, cmap="gray")
ax[0, 1].set_title("Gray Scale")
ax[0, 1].axis("off")

ax[1, 0].imshow(img_kernel_v, cmap="gray")
ax[1, 0].set_title("Vertical Kernel Convolution")
ax[1, 0].axis("off")

ax[1, 1].imshow(img_kernel_h, cmap="gray")
ax[1, 1].set_title("Horizontal Kernel Convolution")
ax[1, 1].axis("off")

plt.show()
